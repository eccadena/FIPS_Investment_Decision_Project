# %%
import pandas as pd


food_desert = pd.read_excel('../data/rawdata/fooddesert.xlsx', sheet_name='Food Access Research Atlas')

# %%
cols = food_desert.columns.tolist() # reran after index was reset
print(cols)
# Out:
# ['CensusTract', 'State', 'County', 'Urban', 'POP2010', 'OHU2010', 'GroupQuartersFlag', 'NUMGQTRS', 'PCTGQTRS', 'LILATracts_1And10', 'LILATracts_halfAnd10', 'LILATracts_1And20', 'LILATracts_Vehicle', 'HUNVFlag', 'LowIncomeTracts', 'PovertyRate', 'MedianFamilyIncome', 'LA1and10', 'LAhalfand10', 'LA1and20', 'LATracts_half', 'LATracts1', 'LATracts10', 'LATracts20', 'LATractsVehicle_20', 'LAPOP1_10', 'LAPOP05_10', 'LAPOP1_20', 'LALOWI1_10', 'LALOWI05_10', 'LALOWI1_20', 'lapophalf', 'lapophalfshare', 'lalowihalf', 'lalowihalfshare', 'lakidshalf', 'lakidshalfshare', 'laseniorshalf', 'laseniorshalfshare', 'lawhitehalf', 'lawhitehalfshare', 'lablackhalf', 'lablackhalfshare', 'laasianhalf', 'laasianhalfshare', 'lanhopihalf', 'lanhopihalfshare', 'laaianhalf', 'laaianhalfshare', 'laomultirhalf', 'laomultirhalfshare', 'lahisphalf', 'lahisphalfshare', 'lahunvhalf', 'lahunvhalfshare', 'lasnaphalf', 'lasnaphalfshare', 'lapop1', 'lapop1share', 'lalowi1', 'lalowi1share', 'lakids1', 'lakids1share', 'laseniors1', 'laseniors1share', 'lawhite1', 'lawhite1share', 'lablack1', 'lablack1share', 'laasian1', 'laasian1share', 'lanhopi1', 'lanhopi1share', 'laaian1', 'laaian1share', 'laomultir1', 'laomultir1share', 'lahisp1', 'lahisp1share', 'lahunv1', 'lahunv1share', 'lasnap1', 'lasnap1share', 'lapop10', 'lapop10share', 'lalowi10', 'lalowi10share', 'lakids10', 'lakids10share', 'laseniors10', 'laseniors10share', 'lawhite10', 'lawhite10share', 'lablack10', 'lablack10share', 'laasian10', 'laasian10share', 'lanhopi10', 'lanhopi10share', 'laaian10', 'laaian10share', 'laomultir10', 'laomultir10share', 'lahisp10', 'lahisp10share', 'lahunv10', 'lahunv10share', 'lasnap10', 'lasnap10share', 'lapop20', 'lapop20share', 'lalowi20', 'lalowi20share', 'lakids20', 'lakids20share', 'laseniors20', 'laseniors20share', 'lawhite20', 'lawhite20share', 'lablack20', 'lablack20share', 'laasian20', 'laasian20share', 'lanhopi20', 'lanhopi20share', 'laaian20', 'laaian20share', 'laomultir20', 'laomultir20share', 'lahisp20', 'lahisp20share', 'lahunv20', 'lahunv20share', 'lasnap20', 'lasnap20share', 'TractLOWI', 'TractKids', 'TractSeniors', 'TractWhite', 'TractBlack', 'TractAsian', 'TractNHOPI', 'TractAIAN', 'TractOMultir', 'TractHispanic', 'TractHUNV', 'TractSNAP']

# %%
food_desert['CensusTract'].is_unique #no repeat FIPS
# Out:
# True

# %%
food_desert.set_index('CensusTract', inplace=True) # called once, needs to be silenced if cell ran twice. #index willl throw an error.
food_desert.head()
# Out:
#                State   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# CensusTract
# 1001020100   Alabama  Autauga      1     1912      693                  0
# 1001020200   Alabama  Autauga      1     2170      743                  0
# 1001020300   Alabama  Autauga      1     3373     1256                  0
# 1001020400   Alabama  Autauga      1     4386     1722                  0
# 1001020500   Alabama  Autauga      1    10766     4082                  0
#
#              NUMGQTRS  PCTGQTRS  LILATracts_1And10  LILATracts_halfAnd10  ...  \
# CensusTract                                                               ...
# 1001020100          0  0.000000                  0                     0  ...
# 1001020200        181  0.083410                  0                     0  ...
# 1001020300          0  0.000000                  0                     0  ...
# 1001020400          0  0.000000                  0                     0  ...
# 1001020500        181  0.016812                  0                     0  ...
#
#              TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  \
# CensusTract
# 1001020100            221        1622         217          14           0
# 1001020200            214         888        1217           5           0
# 1001020300            439        2576         647          17           5
# 1001020400            904        4086         193          18           4
# 1001020500           1126        8666        1437         296           9
#
#              TractAIAN  TractOMultir  TractHispanic  TractHUNV  TractSNAP
# CensusTract
# 1001020100          14            45             44         26        112
# 1001020200           5            55             75         87        202
# 1001020300          11           117             87        108        120
# 1001020400          11            74             85         19         82
# 1001020500          48           310            355        198        488
#
# [5 rows x 146 columns]

# %%
# food_desert.loc[1001020500] #calling directly to the FIPS
# Out:
# State                     Alabama
# County                    Autauga
# Urban                           1
# POP2010                     10766
# OHU2010                      4082
# GroupQuartersFlag               0
# NUMGQTRS                      181
# PCTGQTRS                0.0168122
# LILATracts_1And10               0
# LILATracts_halfAnd10            0
# LILATracts_1And20               0
# LILATracts_Vehicle              0
# HUNVFlag                        1
# LowIncomeTracts                 0
# PovertyRate                   8.5
# MedianFamilyIncome          77819
# LA1and10                        1
# LAhalfand10                     1
# LA1and20                        1
# LATracts_half                   1
# LATracts1                       1
# LATracts10                      0
# LATracts20                      0
# LATractsVehicle_20              1
# LAPOP1_10                  2643.1
# LAPOP05_10                 7778.4
# LAPOP1_20                  2643.1
# LALOWI1_10                623.077
# LALOWI05_10               1913.45
# LALOWI1_20                623.077
#                           ...
# lawhite20                       0
# lawhite20share                  0
# lablack20                       0
# lablack20share                  0
# laasian20                       0
# laasian20share                  0
# lanhopi20                       0
# lanhopi20share                  0
# laaian20                        0
# laaian20share                   0
# laomultir20                     0
# laomultir20share                0
# lahisp20                        0
# lahisp20share                   0
# lahunv20                        0
# lahunv20share                   0
# lasnap20                        0
# lasnap20share                   0
# TractLOWI                    2692
# TractKids                    3162
# TractSeniors                 1126
# TractWhite                   8666
# TractBlack                   1437
# TractAsian                    296
# TractNHOPI                      9
# TractAIAN                      48
# TractOMultir                  310
# TractHispanic                 355
# TractHUNV                     198
# TractSNAP                     488
# Name: 1001020500, Length: 146, dtype: object

# %%
food_desert.get_dtype_counts()
# Out:
# float64    112
# int64       32
# object       2
# dtype: int64

# %%
food_desert.isnull().sum() #they are all zero! yay
# Out:
# State                   0
# County                  0
# Urban                   0
# POP2010                 0
# OHU2010                 0
# GroupQuartersFlag       0
# NUMGQTRS                0
# PCTGQTRS                0
# LILATracts_1And10       0
# LILATracts_halfAnd10    0
# LILATracts_1And20       0
# LILATracts_Vehicle      0
# HUNVFlag                0
# LowIncomeTracts         0
# PovertyRate             0
# MedianFamilyIncome      0
# LA1and10                0
# LAhalfand10             0
# LA1and20                0
# LATracts_half           0
# LATracts1               0
# LATracts10              0
# LATracts20              0
# LATractsVehicle_20      0
# LAPOP1_10               0
# LAPOP05_10              0
# LAPOP1_20               0
# LALOWI1_10              0
# LALOWI05_10             0
# LALOWI1_20              0
#                        ..
# lawhite20               0
# lawhite20share          0
# lablack20               0
# lablack20share          0
# laasian20               0
# laasian20share          0
# lanhopi20               0
# lanhopi20share          0
# laaian20                0
# laaian20share           0
# laomultir20             0
# laomultir20share        0
# lahisp20                0
# lahisp20share           0
# lahunv20                0
# lahunv20share           0
# lasnap20                0
# lasnap20share           0
# TractLOWI               0
# TractKids               0
# TractSeniors            0
# TractWhite              0
# TractBlack              0
# TractAsian              0
# TractNHOPI              0
# TractAIAN               0
# TractOMultir            0
# TractHispanic           0
# TractHUNV               0
# TractSNAP               0
# Length: 146, dtype: int64

# %%
cols = food_desert.columns.tolist() #update after drop
# Out:
# State is unique: False
# County is unique: False
# Urban is unique: False
# POP2010 is unique: False
# OHU2010 is unique: False
# GroupQuartersFlag is unique: False
# NUMGQTRS is unique: False
# PCTGQTRS is unique: False
# LILATracts_1And10 is unique: False
# LILATracts_halfAnd10 is unique: False
# LILATracts_1And20 is unique: False
# LILATracts_Vehicle is unique: False
# HUNVFlag is unique: False
# LowIncomeTracts is unique: False
# PovertyRate is unique: False
# MedianFamilyIncome is unique: False
# LA1and10 is unique: False
# LAhalfand10 is unique: False
# LA1and20 is unique: False
# LATracts_half is unique: False
# LATracts1 is unique: False
# LATracts10 is unique: False
# LATracts20 is unique: False
# LATractsVehicle_20 is unique: False
# LAPOP1_10 is unique: False
# LAPOP05_10 is unique: False
# LAPOP1_20 is unique: False
# LALOWI1_10 is unique: False
# LALOWI05_10 is unique: False
# LALOWI1_20 is unique: False
# lapophalf is unique: False
# lapophalfshare is unique: False
# lalowihalf is unique: False
# lalowihalfshare is unique: False
# lakidshalf is unique: False
# lakidshalfshare is unique: False
# laseniorshalf is unique: False
# laseniorshalfshare is unique: False
# lawhitehalf is unique: False
# lawhitehalfshare is unique: False
# lablackhalf is unique: False
# lablackhalfshare is unique: False
# laasianhalf is unique: False
# laasianhalfshare is unique: False
# lanhopihalf is unique: False
# lanhopihalfshare is unique: False
# laaianhalf is unique: False
# laaianhalfshare is unique: False
# laomultirhalf is unique: False
# laomultirhalfshare is unique: False
# lahisphalf is unique: False
# lahisphalfshare is unique: False
# lahunvhalf is unique: False
# lahunvhalfshare is unique: False
# lasnaphalf is unique: False
# lasnaphalfshare is unique: False
# lapop1 is unique: False
# lapop1share is unique: False
# lalowi1 is unique: False
# lalowi1share is unique: False
# lakids1 is unique: False
# lakids1share is unique: False
# laseniors1 is unique: False
# laseniors1share is unique: False
# lawhite1 is unique: False
# lawhite1share is unique: False
# lablack1 is unique: False
# lablack1share is unique: False
# laasian1 is unique: False
# laasian1share is unique: False
# lanhopi1 is unique: False
# lanhopi1share is unique: False
# laaian1 is unique: False
# laaian1share is unique: False
# laomultir1 is unique: False
# laomultir1share is unique: False
# lahisp1 is unique: False
# lahisp1share is unique: False
# lahunv1 is unique: False
# lahunv1share is unique: False
# lasnap1 is unique: False
# lasnap1share is unique: False
# lapop10 is unique: False
# lapop10share is unique: False
# lalowi10 is unique: False
# lalowi10share is unique: False
# lakids10 is unique: False
# lakids10share is unique: False
# laseniors10 is unique: False
# laseniors10share is unique: False
# lawhite10 is unique: False
# lawhite10share is unique: False
# lablack10 is unique: False
# lablack10share is unique: False
# laasian10 is unique: False
# laasian10share is unique: False
# lanhopi10 is unique: False
# lanhopi10share is unique: False
# laaian10 is unique: False
# laaian10share is unique: False
# laomultir10 is unique: False
# laomultir10share is unique: False
# lahisp10 is unique: False
# lahisp10share is unique: False
# lahunv10 is unique: False
# lahunv10share is unique: False
# lasnap10 is unique: False
# lasnap10share is unique: False
# lapop20 is unique: False
# lapop20share is unique: False
# lalowi20 is unique: False
# lalowi20share is unique: False
# lakids20 is unique: False
# lakids20share is unique: False
# laseniors20 is unique: False
# laseniors20share is unique: False
# lawhite20 is unique: False
# lawhite20share is unique: False
# lablack20 is unique: False
# lablack20share is unique: False
# laasian20 is unique: False
# laasian20share is unique: False
# lanhopi20 is unique: False
# lanhopi20share is unique: False
# laaian20 is unique: False
# laaian20share is unique: False
# laomultir20 is unique: False
# laomultir20share is unique: False
# lahisp20 is unique: False
# lahisp20share is unique: False
# lahunv20 is unique: False
# lahunv20share is unique: False
# lasnap20 is unique: False
# lasnap20share is unique: False
# TractLOWI is unique: False
# TractKids is unique: False
# TractSeniors is unique: False
# TractWhite is unique: False
# TractBlack is unique: False
# TractAsian is unique: False
# TractNHOPI is unique: False
# TractAIAN is unique: False
# TractOMultir is unique: False
# TractHispanic is unique: False
# TractHUNV is unique: False
# TractSNAP is unique: False

# %%
texas_food_desert = food_desert[food_desert['State'] == 'Texas']

# %%
texas_food_desert_harris = texas_food_desert[texas_food_desert['County'] == 'Harris']

# %%
texas_food_desert_harris.head()
# Out:
#              State  County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# CensusTract
# 48201100000  Texas  Harris      1     4690     1737                  0
# 48201210100  Texas  Harris      1     9652       72                  1
# 48201210400  Texas  Harris      1     5328     1593                  0
# 48201210500  Texas  Harris      1     4882     1504                  0
# 48201210600  Texas  Harris      1     5497     2037                  0
#
#              NUMGQTRS  PCTGQTRS  LILATracts_1And10  LILATracts_halfAnd10  ...  \
# CensusTract                                                               ...
# 48201100000      2407  0.513220                  0                     0  ...
# 48201210100      9551  0.989536                  0                     0  ...
# 48201210400       257  0.048236                  0                     1  ...
# 48201210500        61  0.012495                  0                     1  ...
# 48201210600         0  0.000000                  0                     1  ...
#
#              TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  \
# CensusTract
# 48201100000           159        2669        1068         137           1
# 48201210100            49        4515        4903          61           0
# 48201210400           455        2617         931          26           4
# 48201210500           523        2532         558          11           0
# 48201210600           725        3832         117          41           1
#
#              TractAIAN  TractOMultir  TractHispanic  TractHUNV  TractSNAP
# CensusTract
# 48201100000         25           790           1070        360         50
# 48201210100          3           170           1788          5          0
# 48201210400         43          1707           4025        354        564
# 48201210500         30          1751           4096        291        458
# 48201210600         53          1453           4378        198        229
#
# [5 rows x 146 columns]

# %%
# XLSX has a sheet with information on all Columns. pd.read_clipboard on this sheet plus an added column on whether to keep or drop this column for our MVP.
tract_info = pd.read_clipboard()
tract_info.head()
# Out:
#   Keep?        Field                 LongName  \
# 0     y  CensusTract             Census tract
# 1     y        State                    State
# 2     y       County                   County
# 3     y        Urban              Urban tract
# 4     n      POP2010  Population, tract total
#
#                          Description
# 0                Census tract number
# 1                         State name
# 2                        County name
# 3               Flag for urban tract
# 4  Population count from 2010 census

# %%
col_drop = tract_info[tract_info['Keep?'] == 'n']
list_col_drop = col_drop['Field'].to_list()
list_col_drop
# Out:
# ['POP2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'LILATracts_1And10',
#  'LILATracts_halfAnd10',
#  'LILATracts_1And20',
#  'LILATracts_Vehicle',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LAPOP1_10',
#  'LAPOP05_10',
#  'LAPOP1_20',
#  'LALOWI1_10',
#  'LALOWI05_10',
#  'LALOWI1_20',
#  'lapophalf',
#  'lapophalfshare',
#  'lalowihalf',
#  'lalowihalfshare',
#  'lakidshalf',
#  'lakidshalfshare',
#  'laseniorshalf',
#  'laseniorshalfshare',
#  'lawhitehalf',
#  'lawhitehalfshare',
#  'lablackhalf',
#  'lablackhalfshare',
#  'laasianhalf',
#  'laasianhalfshare',
#  'lanhopihalf',
#  'lanhopihalfshare',
#  'laaianhalf',
#  'laaianhalfshare',
#  'laomultirhalf',
#  'laomultirhalfshare',
#  'lahisphalf',
#  'lahisphalfshare',
#  'lahunvhalf',
#  'lahunvhalfshare',
#  'lasnaphalf',
#  'lasnaphalfshare',
#  'lapop1',
#  'lapop1share',
#  'lalowi1',
#  'lalowi1share',
#  'lakids1',
#  'lakids1share',
#  'laseniors1',
#  'laseniors1share',
#  'lawhite1',
#  'lawhite1share',
#  'lablack1',
#  'lablack1share',
#  'laasian1',
#  'laasian1share',
#  'lanhopi1',
#  'lanhopi1share',
#  'laaian1',
#  'laaian1share',
#  'laomultir1',
#  'laomultir1share',
#  'lahisp1',
#  'lahisp1share',
#  'lahunv1',
#  'lahunv1share',
#  'lasnap1',
#  'lasnap1share',
#  'lapop10',
#  'lapop10share',
#  'lalowi10',
#  'lalowi10share',
#  'lakids10',
#  'lakids10share',
#  'laseniors10',
#  'laseniors10share',
#  'lawhite10',
#  'lawhite10share',
#  'lablack10',
#  'lablack10share',
#  'laasian10',
#  'laasian10share',
#  'lanhopi10',
#  'lanhopi10share',
#  'laaian10',
#  'laaian10share',
#  'laomultir10',
#  'laomultir10share',
#  'lahisp10',
#  'lahisp10share',
#  'lahunv10',
#  'lahunv10share',
#  'lasnap10',
#  'lasnap10share',
#  'lapop20',
#  'lapop20share',
#  'lalowi20',
#  'lalowi20share',
#  'lakids20',
#  'lakids20share',
#  'laseniors20',
#  'laseniors20share',
#  'lawhite20',
#  'lawhite20share',
#  'lablack20',
#  'lablack20share',
#  'laasian20',
#  'laasian20share',
#  'lanhopi20',
#  'lanhopi20share',
#  'laaian20',
#  'laaian20share',
#  'laomultir20',
#  'laomultir20share',
#  'lahisp20',
#  'lahisp20share',
#  'lahunv20',
#  'lahunv20share',
#  'lasnap20',
#  'lasnap20share',
#  'TractLOWI',
#  'TractKids',
#  'TractSeniors',
#  'TractWhite',
#  'TractBlack',
#  'TractAsian',
#  'TractNHOPI',
#  'TractAIAN',
#  'TractOMultir',
#  'TractHispanic',
#  'TractHUNV',
#  'TractSNAP']

# %%
TX_Food_Desert_Data = texas_food_desert_harris.drop(columns = list_col_drop)
TX_Food_Desert_Data.rename(columns = {'CensusTract':'FIPS'}, inplace = True)

# %%
from pathlib import Path

output_path = Path("../data/cleandata/food_desert.csv")

with open(output_path, 'w') as file:
    file.write(TX_Food_Desert_Data.to_csv())
